# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Winter months, indirectWue boxplot


start_date = pd.Timestamp('2023-01-01')
end_date = pd.Timestamp('2023-03-31')

df_be = pd.read_csv('TotalWue_Belgium.csv')
df_be['start_time'] = pd.to_datetime(df_be['MTU'].str.split().str[0], format='%d.%m.%Y')
df_be = df_be.loc[(df_be['start_time'] >= start_date) & (df_be['start_time'] <= end_date)]
df_be['Country'] = 'St. Ghislain, Belgium'
df_be['indirectWue L/kWh'] = df_be['indirectWue gal/kWh'] * 3.78541

df_dk = pd.read_csv('TotalWue_Denmark.csv')
df_dk['start_time'] = pd.to_datetime(df_dk['MTU'].str.split().str[0], format='%d.%m.%Y')
df_dk = df_dk.loc[(df_dk['start_time'] >= start_date) & (df_dk['start_time'] <= end_date)]
df_dk['Country'] = 'Fredericia, Denmark'
df_dk['indirectWue L/kWh'] = df_dk['indirectWue gal/kWh'] * 3.78541

df_fi = pd.read_csv('TotalWue_Finland.csv')
df_fi['start_time'] = pd.to_datetime(df_fi['MTU'].str.split().str[0], format='%d.%m.%Y')
df_fi = df_fi.loc[(df_fi['start_time'] >= start_date) & (df_fi['start_time'] <= end_date)]
df_fi['Country'] = 'Hamina, Finland'
df_fi['indirectWue L/kWh'] = df_fi['indirectWue gal/kWh'] * 3.78541

df_de = pd.read_csv('TotalWue_Germany.csv')
df_de['start_time'] = pd.to_datetime(df_de['MTU'].str.split().str[0], format='%d.%m.%Y')
df_de = df_de.loc[(df_de['start_time'] >= start_date) & (df_de['start_time'] <= end_date)]
df_de['Country'] = 'Hanau, Germany'
df_de['indirectWue L/kWh'] = df_de['indirectWue gal/kWh'] * 3.78541

df_ie = pd.read_csv('TotalWue_Ireland.csv')
df_ie['start_time'] = pd.to_datetime(df_ie['MTU'].str.split().str[0], format='%d.%m.%Y')
df_ie = df_ie.loc[(df_ie['start_time'] >= start_date) & (df_ie['start_time'] <= end_date)]
df_ie['Country'] = 'Dublin, Ireland'
df_ie['indirectWue L/kWh'] = df_ie['indirectWue gal/kWh'] * 3.78541

df_n1 = pd.read_csv("TotalWue_Netherlands1.csv")
df_n1['start_time'] = pd.to_datetime(df_n1['MTU'].str.split().str[0], format='%d.%m.%Y')
df_n1 = df_n1.loc[(df_n1['start_time'] >= start_date) & (df_n1['start_time'] <= end_date)]
df_n1['Country'] = 'Eemshaven, Netherlands'
df_n1['indirectWue L/kWh'] = df_n1["indirectWue gal/kWh"] * 3.78541

df_n2 = pd.read_csv("TotalWue_Netherlands2.csv")
df_n2['start_time'] = pd.to_datetime(df_n2['MTU'].str.split().str[0], format='%d.%m.%Y')
df_n2 = df_n2.loc[(df_n2['start_time'] >= start_date) & (df_n2['start_time'] <= end_date)]
df_n2['Country'] = 'Middenmeer, Netherlands'
df_n2['indirectWue L/kWh'] = df_n2["indirectWue gal/kWh"] * 3.78541

df_no = pd.read_csv("TotalWue_Norway.csv")
df_no['start_time'] = pd.to_datetime(df_no['MTU'].str.split().str[0], format='%d.%m.%Y')
df_no = df_no.loc[(df_no['start_time'] >= start_date) & (df_no['start_time'] <= end_date)]
df_no['Country'] = 'Skien, Norway'
df_no['indirectWue L/kWh'] = df_no["indirectWue gal/kWh"] * 3.78541

df_uk = pd.read_csv("TotalWue_UK.csv")
df_uk['start_time'] = pd.to_datetime(df_uk['MTU'].str.split().str[0], format='%d.%m.%Y')
df_uk = df_uk.loc[(df_uk['start_time'] >= start_date) & (df_uk['start_time'] <= end_date)]
df_uk['Country'] = 'Waltham Cross, UK'
df_uk['indirectWue L/kWh'] = df_uk["indirectWue gal/kWh"] * 3.78541



combined_df = pd.concat([df_be, df_dk, df_fi, df_de, df_ie, df_n1, df_n2, df_no, df_uk], ignore_index=True)

plt.figure(figsize=(12, 8))

sns.boxplot(x='Country', y='indirectWue L/kWh', data=combined_df, showmeans=True, showfliers = False,
    boxprops={"facecolor": "lightgreen", "linewidth": 3},
    medianprops={"color": "black", "linewidth": 1.5},
    meanprops={"marker": "D", "markerfacecolor": "yellow", "markeredgecolor": "black"},
    whiskerprops={"linestyle": "-", "linewidth": 2, "color": "black"})

plt.title('Indirect WUE During Winter')
plt.xlabel('Country')
plt.ylabel('WUE (L/kWh)')
plt.xticks(rotation=90, ha='right', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-cdf865e808af>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_be['Country'] = 'St. Ghislain, Belgium'
# <ipython-input-6-cdf865e808af>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_be['indirectWue L/kWh'] = df_be['indirectWue gal/kWh'] * 3.78541

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Spring months, indirectWue boxplot

start_date = pd.Timestamp('2023-03-31')
end_date = pd.Timestamp('2023-06-01')

df_be = pd.read_csv('TotalWue_Belgium.csv')df_be['start_time'] = pd.to_datetime(df_be['MTU'].str.split().str[0], format='%d.%m.%Y')
df_be = df_be.loc[(df_be['start_time'] >= start_date) & (df_be['start_time'] <= end_date)]
df_be['Country'] = 'St. Ghislain, Belgium'
df_be['indirectWue L/kWh'] = df_be['indirectWue gal/kWh'] * 3.78541


df_dk = pd.read_csv('TotalWue_Denmark.csv')
df_dk['start_time'] = pd.to_datetime(df_dk['MTU'].str.split().str[0], format='%d.%m.%Y')
df_dk = df_dk.loc[(df_dk['start_time'] >= start_date) & (df_dk['start_time'] <= end_date)]
df_dk['Country'] = 'Fredericia, Denmark'
df_dk['indirectWue L/kWh'] = df_dk['indirectWue gal/kWh'] * 3.78541


df_fi = pd.read_csv('TotalWue_Finland.csv')
df_fi['start_time'] = pd.to_datetime(df_fi['MTU'].str.split().str[0], format='%d.%m.%Y')
df_fi = df_fi.loc[(df_fi['start_time'] >= start_date) & (df_fi['start_time'] <= end_date)]
df_fi['Country'] = 'Hamina, Finland'
df_fi['indirectWue L/kWh'] = df_fi['indirectWue gal/kWh'] * 3.78541


df_de = pd.read_csv('TotalWue_Germany.csv')
df_de['start_time'] = pd.to_datetime(df_de['MTU'].str.split().str[0], format='%d.%m.%Y')
df_de = df_de.loc[(df_de['start_time'] >= start_date) & (df_de['start_time'] <= end_date)]
df_de['Country'] = 'Hanau, Germany'
df_de['indirectWue L/kWh'] = df_de['indirectWue gal/kWh'] * 3.78541

df_ie = pd.read_csv('TotalWue_Ireland.csv')
df_ie['start_time'] = pd.to_datetime(df_ie['MTU'].str.split().str[0], format='%d.%m.%Y')
df_ie = df_ie.loc[(df_ie['start_time'] >= start_date) & (df_ie['start_time'] <= end_date)]
df_ie['Country'] = 'Dublin, Ireland'
df_ie['indirectWue L/kWh'] = df_ie['indirectWue gal/kWh'] * 3.78541

df_n1 = pd.read_csv("TotalWue_Netherlands1.csv")
df_n1['start_time'] = pd.to_datetime(df_n1['MTU'].str.split().str[0], format='%d.%m.%Y')
df_n1 = df_n1.loc[(df_n1['start_time'] >= start_date) & (df_n1['start_time'] <= end_date)]
df_n1['Country'] = 'Eemshaven, Netherlands'
df_n1['indirectWue L/kWh'] = df_n1["indirectWue gal/kWh"] * 3.78541

df_n2 = pd.read_csv("TotalWue_Netherlands2.csv")
df_n2['start_time'] = pd.to_datetime(df_n2['MTU'].str.split().str[0], format='%d.%m.%Y')
df_n2 = df_n2.loc[(df_n2['start_time'] >= start_date) & (df_n2['start_time'] <= end_date)]
df_n2['Country'] = 'Middenmeer, Netherlands'
df_n2['indirectWue L/kWh'] = df_n2["indirectWue gal/kWh"] * 3.78541

df_no = pd.read_csv("TotalWue_Norway.csv")
df_no['start_time'] = pd.to_datetime(df_no['MTU'].str.split().str[0], format='%d.%m.%Y')
df_no = df_no.loc[(df_no['start_time'] >= start_date) & (df_no['start_time'] <= end_date)]
df_no['Country'] = 'Skien, Norway'
df_no['indirectWue L/kWh'] = df_no["indirectWue gal/kWh"] * 3.78541

df_uk = pd.read_csv("TotalWue_UK.csv")
df_uk['start_time'] = pd.to_datetime(df_uk['MTU'].str.split().str[0], format='%d.%m.%Y')
df_uk = df_uk.loc[(df_uk['start_time'] >= start_date) & (df_uk['start_time'] <= end_date)]
df_uk['Country'] = 'Waltham Cross, UK'
df_uk['indirectWue L/kWh'] = df_uk["indirectWue gal/kWh"] * 3.78541



combined_df = pd.concat([df_be, df_dk, df_fi, df_de, df_ie, df_n1, df_n2, df_no, df_uk], ignore_index=True)

plt.figure(figsize=(12, 8))

sns.boxplot(x='Country', y='indirectWue L/kWh', data=combined_df, showmeans=True, showfliers = False,
    boxprops={"facecolor": "lightgreen", "linewidth": 3},
    medianprops={"color": "black", "linewidth": 1.5},
    meanprops={"marker": "D", "markerfacecolor": "yellow", "markeredgecolor": "black"},
    whiskerprops={"linestyle": "-", "linewidth": 2, "color": "black"})

plt.title('Indirect WUE During Spring')
plt.xlabel('Country')
plt.ylabel('WUE (L/kWh)')
plt.xticks(rotation=90, ha='right', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-7-328fc14a1ce6>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_de['Country'] = 'Hanau, Germany'
# <ipython-input-7-328fc14a1ce6>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_de['indirectWue L/kWh'] = df_de['indirectWue gal/kWh'] * 3.78541
# <ipython-input-7-328fc14a1ce6>:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Summer months, indirectWue boxplot

start_date = pd.Timestamp('2023-06-01')
end_date = pd.Timestamp('2023-09-01')

df_be = pd.read_csv('TotalWue_Belgium.csv')
df_be['start_time'] = pd.to_datetime(df_be['MTU'].str.split().str[0], format='%d.%m.%Y')
df_be = df_be.loc[(df_be['start_time'] >= start_date) & (df_be['start_time'] <= end_date)]
df_be['Country'] = 'St. Ghislain, Belgium'
df_be['indirectWue L/kWh'] = df_be['indirectWue gal/kWh'] * 3.78541

df_dk = pd.read_csv('TotalWue_Denmark.csv')
df_dk['start_time'] = pd.to_datetime(df_dk['MTU'].str.split().str[0], format='%d.%m.%Y')
df_dk = df_dk.loc[(df_dk['start_time'] >= start_date) & (df_dk['start_time'] <= end_date)]
df_dk['Country'] = 'Fredericia, Denmark'
df_dk['indirectWue L/kWh'] = df_dk['indirectWue gal/kWh'] * 3.78541

df_fi = pd.read_csv('TotalWue_Finland.csv')
df_fi['start_time'] = pd.to_datetime(df_fi['MTU'].str.split().str[0], format='%d.%m.%Y')
df_fi = df_fi.loc[(df_fi['start_time'] >= start_date) & (df_fi['start_time'] <= end_date)]
df_fi['Country'] = 'Hamina, Finland'
df_fi['indirectWue L/kWh'] = df_fi['indirectWue gal/kWh'] * 3.78541

df_de = pd.read_csv('TotalWue_Germany.csv')
df_de['start_time'] = pd.to_datetime(df_de['MTU'].str.split().str[0], format='%d.%m.%Y')
df_de = df_de.loc[(df_de['start_time'] >= start_date) & (df_de['start_time'] <= end_date)]
df_de['Country'] = 'Hanau, Germany'
df_de['indirectWue L/kWh'] = df_de['indirectWue gal/kWh'] * 3.78541

df_ie = pd.read_csv('TotalWue_Ireland.csv')
df_ie['start_time'] = pd.to_datetime(df_ie['MTU'].str.split().str[0], format='%d.%m.%Y')
df_ie = df_ie.loc[(df_ie['start_time'] >= start_date) & (df_ie['start_time'] <= end_date)]
df_ie['Country'] = 'Dublin, Ireland'
df_ie['indirectWue L/kWh'] = df_ie['indirectWue gal/kWh'] * 3.78541

df_n1 = pd.read_csv("TotalWue_Netherlands1.csv")
df_n1['start_time'] = pd.to_datetime(df_n1['MTU'].str.split().str[0], format='%d.%m.%Y')
df_n1 = df_n1.loc[(df_n1['start_time'] >= start_date) & (df_n1['start_time'] <= end_date)]
df_n1['Country'] = 'Eemshaven, Netherlands'
df_n1['indirectWue L/kWh'] = df_n1["indirectWue gal/kWh"] * 3.78541

df_n2 = pd.read_csv("TotalWue_Netherlands2.csv")
df_n2['start_time'] = pd.to_datetime(df_n2['MTU'].str.split().str[0], format='%d.%m.%Y')
df_n2 = df_n2.loc[(df_n2['start_time'] >= start_date) & (df_n2['start_time'] <= end_date)]
df_n2['Country'] = 'Middenmeer, Netherlands'
df_n2['indirectWue L/kWh'] = df_n2["indirectWue gal/kWh"] * 3.78541

df_no = pd.read_csv("TotalWue_Norway.csv")
df_no['start_time'] = pd.to_datetime(df_no['MTU'].str.split().str[0], format='%d.%m.%Y')
df_no = df_no.loc[(df_no['start_time'] >= start_date) & (df_no['start_time'] <= end_date)]
df_no['Country'] = 'Skien, Norway'
df_no['indirectWue L/kWh'] = df_no["indirectWue gal/kWh"] * 3.78541

df_uk = pd.read_csv("TotalWue_UK.csv")
df_uk['start_time'] = pd.to_datetime(df_uk['MTU'].str.split().str[0], format='%d.%m.%Y')
df_uk = df_uk.loc[(df_uk['start_time'] >= start_date) & (df_uk['start_time'] <= end_date)]
df_uk['Country'] = 'Waltham Cross, UK'
df_uk['indirectWue L/kWh'] = df_uk["indirectWue gal/kWh"] * 3.78541


combined_df = pd.concat([df_be, df_dk, df_fi, df_de, df_ie, df_n1, df_n2, df_no, df_uk], ignore_index=True)

plt.figure(figsize=(12, 8))

sns.boxplot(x='Country', y='indirectWue L/kWh', data=combined_df, showmeans=True, showfliers = False,
    boxprops={"facecolor": "lightgreen", "linewidth": 3},
    medianprops={"color": "black", "linewidth": 1.5},
    meanprops={"marker": "D", "markerfacecolor": "yellow", "markeredgecolor": "black"},
    whiskerprops={"linestyle": "-", "linewidth": 2, "color": "black"})

plt.title('Indirect WUE During Summer')
plt.xlabel('Country')
plt.ylabel('WUE (L/kWh)')
plt.xticks(rotation=90, ha='right', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-65def0b7e22f>:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_n2['Country'] = 'Middenmeer, Netherlands'
# <ipython-input-8-65def0b7e22f>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_n2['indirectWue L/kWh'] = df_n2["indirectWue gal/kWh"] * 3.78541

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Fall months, indirectWue boxplot

start_date = pd.Timestamp('2023-09-01')
end_date = pd.Timestamp('2023-12-21')

df_be = pd.read_csv('TotalWue_Belgium.csv')
df_be['start_time'] = pd.to_datetime(df_be['MTU'].str.split().str[0], format='%d.%m.%Y')
df_be = df_be.loc[(df_be['start_time'] >= start_date) & (df_be['start_time'] <= end_date)]
df_be['Country'] = 'St. Ghislain, Belgium'
df_be['indirectWue L/kWh'] = df_be['indirectWue gal/kWh'] * 3.78541

df_dk = pd.read_csv('TotalWue_Denmark.csv')
df_dk['start_time'] = pd.to_datetime(df_dk['MTU'].str.split().str[0], format='%d.%m.%Y')
df_dk = df_dk.loc[(df_dk['start_time'] >= start_date) & (df_dk['start_time'] <= end_date)]
df_dk['Country'] = 'Fredericia, Denmark'
df_dk['indirectWue L/kWh'] = df_dk['indirectWue gal/kWh'] * 3.78541

df_fi = pd.read_csv('TotalWue_Finland.csv')
df_fi['start_time'] = pd.to_datetime(df_fi['MTU'].str.split().str[0], format='%d.%m.%Y')
df_fi = df_fi.loc[(df_fi['start_time'] >= start_date) & (df_fi['start_time'] <= end_date)]
df_fi['Country'] = 'Hamina, Finland'
df_fi['indirectWue L/kWh'] = df_fi['indirectWue gal/kWh'] * 3.78541

df_de = pd.read_csv('TotalWue_Germany.csv')
df_de['start_time'] = pd.to_datetime(df_de['MTU'].str.split().str[0], format='%d.%m.%Y')
df_de = df_de.loc[(df_de['start_time'] >= start_date) & (df_de['start_time'] <= end_date)]
df_de['Country'] = 'Hanau, Germany'
df_de['indirectWue L/kWh'] = df_de['indirectWue gal/kWh'] * 3.78541

df_ie = pd.read_csv('TotalWue_Ireland.csv')
df_ie['start_time'] = pd.to_datetime(df_ie['MTU'].str.split().str[0], format='%d.%m.%Y')
df_ie = df_ie.loc[(df_ie['start_time'] >= start_date) & (df_ie['start_time'] <= end_date)]
df_ie['Country'] = 'Dublin, Ireland'
df_ie['indirectWue L/kWh'] = df_ie['indirectWue gal/kWh'] * 3.78541

df_n1 = pd.read_csv("TotalWue_Netherlands1.csv")
df_n1['start_time'] = pd.to_datetime(df_n1['MTU'].str.split().str[0], format='%d.%m.%Y')
df_n1 = df_n1.loc[(df_n1['start_time'] >= start_date) & (df_n1['start_time'] <= end_date)]
df_n1['Country'] = 'Eemshaven, Netherlands'
df_n1['indirectWue L/kWh'] = df_n1["indirectWue gal/kWh"] * 3.78541

df_n2 = pd.read_csv("TotalWue_Netherlands2.csv")
df_n2['start_time'] = pd.to_datetime(df_n2['MTU'].str.split().str[0], format='%d.%m.%Y')
df_n2 = df_n2.loc[(df_n2['start_time'] >= start_date) & (df_n2['start_time'] <= end_date)]
df_n2['Country'] = 'Middenmeer, Netherlands'
df_n2['indirectWue L/kWh'] = df_n2["indirectWue gal/kWh"] * 3.78541

df_no = pd.read_csv("TotalWue_Norway.csv")
df_no['start_time'] = pd.to_datetime(df_no['MTU'].str.split().str[0], format='%d.%m.%Y')
df_no = df_no.loc[(df_no['start_time'] >= start_date) & (df_no['start_time'] <= end_date)]
df_no['Country'] = 'Skien, Norway'
df_no['indirectWue L/kWh'] = df_no["indirectWue gal/kWh"] * 3.78541

df_uk = pd.read_csv("TotalWue_UK.csv")
df_uk['start_time'] = pd.to_datetime(df_uk['MTU'].str.split().str[0], format='%d.%m.%Y')
df_uk = df_uk.loc[(df_uk['start_time'] >= start_date) & (df_uk['start_time'] <= end_date)]
df_uk['Country'] = 'Waltham Cross, UK'
df_uk['indirectWue L/kWh'] = df_uk["indirectWue gal/kWh"] * 3.78541



combined_df = pd.concat([df_be, df_dk, df_fi, df_de, df_ie, df_n1, df_n2, df_no, df_uk], ignore_index=True)

plt.figure(figsize=(12, 8))

sns.boxplot(x='Country', y='indirectWue L/kWh', data=combined_df, showmeans=True, showfliers = False,
    boxprops={"facecolor": "lightgreen", "linewidth": 3},
    medianprops={"color": "black", "linewidth": 1.5},
    meanprops={"marker": "D", "markerfacecolor": "yellow", "markeredgecolor": "black"},
    whiskerprops={"linestyle": "-", "linewidth": 2, "color": "black"})

plt.title('Indirect WUE During Fall')
plt.xlabel('Country')
plt.ylabel('WUE (L/kWh)')
plt.xticks(rotation=90, ha='right', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-7519da109609>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_n1['Country'] = 'Eemshaven, Netherlands'
# <ipython-input-10-7519da109609>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_n1['indirectWue L/kWh'] = df_n1["indirectWue gal/kWh"] * 3.78541

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# percentage change violin plot
# Figure 6

df = pd.read_csv('TotalWue_Belgium.csv')
df_res = pd.read_csv('TotalWue_Denmark.csv')
df1 = pd.read_csv('TotalWue_Finland.csv')
df2 = pd.read_csv('TotalWue_Germany.csv')
df3 = pd.read_csv('TotalWue_Ireland.csv')
df4 = pd.read_csv('TotalWue_Netherlands1.csv')
df5 = pd.read_csv('TotalWue_Netherlands2.csv')
df6 = pd.read_csv('TotalWue_Norway.csv')
df7 = pd.read_csv('TotalWue_UK.csv')


for df in [df, df_res, df1, df2, df3, df4, df5, df6, df7]:
    df['start_time'] = df['MTU'].str.split(' - ').str[0]
    df['start_time'] = df['start_time'].str.split(' \\(').str[0]

for df in [df, df_res, df1, df2, df3, df4, df5, df6, df7]:
    df['start_time'] = pd.to_datetime(df['start_time'], format='%d.%m.%Y %H:%M')


dfs = [df, df_res, df1, df2, df3, df4, df5, df6, df7]

for df in dfs:
    df['indirectWue L/kWh'] = df['indirectWue gal/kWh'] * 3.78541
    df['WUE_percentage_change'] = abs(df['indirectWue L/kWh'].pct_change(periods=24) * 100)
    df.dropna(subset=['WUE_percentage_change'], inplace=True)

all_direct_wue = [df['WUE_percentage_change'] for df in dfs]
all_indirect_wue_df = pd.concat(all_direct_wue, axis=1)
all_indirect_wue_df.columns = ["St. Ghislain, Belgium", "Fredericia, Denmark", "Hamina, Finland", "Hanau, Germany", "Dublin, Ireland",
                             "Eemshaven, Netherlands", "Middenmeer, Netherlands", "Skien, Norway", "Waltham Cross, UK"]
all_indirect_wue_melted = all_indirect_wue_df.melt(var_name="Locations", value_name="Percentage Change (%)")

fig, ax = plt.subplots(figsize=(15, 10))
sb.violinplot(
    x="Locations",
    y="Percentage Change (%)",
    data=all_indirect_wue_melted,
    inner="box",
    linewidth = 2.5,
    color="lightgreen",
    scale="width",
)

plt.title('Percentage Change of WUE Over 24-Hour Periods', fontsize=16)
plt.xlabel('Locations', fontsize=14)
plt.ylabel('Percentage Change (%)', fontsize=14)
plt.ylim(0, 100)
plt.grid(True)
plt.xticks(rotation=90, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-1-f69345c9fc13>:41: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sb.violinplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# boxplot of Belgium showing weekly change
df = pd.read_csv("TotalWue_Belgium.csv")

df["indirectWue L/kWh"] = df["indirectWue gal/kWh"] * 3.78541

df['MTU'] = pd.to_datetime(df['MTU'].str.split().str[0], format='%d.%m.%Y')
df.set_index('MTU', inplace=True)

# set to a certain week but can change
start_date = '2023-01-01'
end_date = '2023-01-07'
df_week = df.loc[start_date:end_date]

fig, ax = plt.subplots(figsize=(12, 8))

sns.boxplot(
    data=df_week,
    x=df_week.index.day_name(),
    y="indirectWue L/kWh",
    color="lightgreen",
    showmeans=True,
    meanprops={"marker": "D", "markerfacecolor": "yellow", "markeredgecolor": "black"},
    medianprops={"color": "black", "linewidth": 1.5},
    whiskerprops={"linestyle": "-", "linewidth": 2, "color": "black"}
)

plt.title("Indirect WUE for Belgium (One Week)", fontsize=16)
plt.ylabel("WUE (L/kWh)", fontsize=14)
plt.xlabel("Days of the Week", fontsize=14)
plt.grid(True)

plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()
