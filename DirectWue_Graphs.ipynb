# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Direct WUE line plot, less messy more clear

# Load data
df = pd.read_csv("TotalWue_Belgium.csv")
df_res = pd.read_csv("TotalWue_Denmark.csv")
df1 = pd.read_csv("TotalWue_Finland.csv")
df2 = pd.read_csv("TotalWue_Germany.csv")
df3 = pd.read_csv("TotalWue_Ireland.csv")
df4 = pd.read_csv("TotalWue_Netherlands1.csv")
df5 = pd.read_csv("TotalWue_Netherlands2.csv")
df6 = pd.read_csv("TotalWue_Norway.csv")
df7 = pd.read_csv("TotalWue_UK.csv")

# Convert gal/kWh to L/kWh
df["directWue L/kWh"] = df["directWue"] * 3.78541
df_res["directWue L/kWh"] = df_res["directWue"] * 3.78541
df1["directWue L/kWh"] = df1["directWue"] * 3.78541
df2["directWue L/kWh"] = df2["directWue"] * 3.78541
df3["directWue L/kWh"] = df3["directWue"] * 3.78541
df4["directWue L/kWh"] = df4["directWue"] * 3.78541
df5["directWue L/kWh"] = df5["directWue"] * 3.78541
df6["directWue L/kWh"] = df6["directWue"] * 3.78541
df7["directWue L/kWh"] = df7["directWue"] * 3.78541

# Parse the Date column
df['MTU'] = pd.to_datetime(df['MTU'].str.split().str[0], format='%d.%m.%Y')
df_res['MTU'] = pd.to_datetime(df_res['MTU'].str.split().str[0], format='%d.%m.%Y')
df1['MTU'] = pd.to_datetime(df1['MTU'].str.split().str[0], format='%d.%m.%Y')
df2['MTU'] = pd.to_datetime(df2['MTU'].str.split().str[0], format='%d.%m.%Y')
df3['MTU'] = pd.to_datetime(df3['MTU'].str.split().str[0], format='%d.%m.%Y')
df4['MTU'] = pd.to_datetime(df4['MTU'].str.split().str[0], format='%d.%m.%Y')
df5['MTU'] = pd.to_datetime(df5['MTU'].str.split().str[0], format='%d.%m.%Y')
df6['MTU'] = pd.to_datetime(df6['MTU'].str.split().str[0], format='%d.%m.%Y')
df7['MTU'] = pd.to_datetime(df7['MTU'].str.split().str[0], format='%d.%m.%Y')

df.set_index('MTU', inplace=True)
df_res.set_index('MTU', inplace=True)
df1.set_index("MTU", inplace = True)
df2.set_index("MTU", inplace = True)
df3.set_index("MTU", inplace = True)
df4.set_index("MTU", inplace = True)
df5.set_index("MTU", inplace = True)
df6.set_index("MTU", inplace = True)
df7.set_index("MTU", inplace = True)

# Plotting
fig, ax = plt.subplots(figsize=(20, 10))

df_smooth = df["directWue L/kWh"].rolling(window = 360).mean()
df_res_smooth = df_res["directWue L/kWh"].rolling(window = 360).mean()
df1_smooth = df1["directWue L/kWh"].rolling(window = 360).mean()
df2_smooth = df2["directWue L/kWh"].rolling(window = 360).mean()
df3_smooth = df3["directWue L/kWh"].rolling(window = 360).mean()
df4_smooth = df4["directWue L/kWh"].rolling(window = 360).mean()
df5_smooth = df5["directWue L/kWh"].rolling(window = 360).mean()
df6_smooth = df6["directWue L/kWh"].rolling(window = 360).mean()
df7_smooth = df7["directWue L/kWh"].rolling(window = 360).mean()

df_smooth.plot(kind='line', ax=ax, alpha=0.6, linewidth = 5, label='St. Ghislain, Belgium', color = 'm')
df_res_smooth.plot(kind='line', ax=ax, alpha=0.6, linewidth = 5, label='Fredericia, Denmark', color = 'c')
df1_smooth.plot(kind='line', ax=ax, alpha=0.6, linewidth = 5, label='Hamina, Finland', color = 'b')
df2_smooth.plot(kind='line', ax=ax, alpha=0.6, linewidth = 5, label='Hanau, Germany', color = 'k')
df3_smooth.plot(kind='line', ax=ax, alpha=0.6, linewidth = 5, label='Dublin, Ireland')
df4_smooth.plot(kind = "line", ax = ax, alpha = 0.6, linewidth = 5, label = "Eemshaven, Netherlands", color = 'r')
df5_smooth.plot(kind = "line", ax = ax, alpha = 0.6, linewidth = 5, label = "Middenmeer, Netherlands", color = 'g')
df6_smooth.plot(kind = "line", ax = ax, alpha = 0.6, linewidth = 5, label = "Skien, Norway", color = 'y')
df7_smooth.plot(kind = "line", ax = ax, alpha = 0.6, linewidth = 5, label = "Waltham Cross, UK", color = 'orange')


# Setting title and labels
plt.title("Direct WUE")
plt.ylabel("WUE (L/kWh)")
plt.xlabel("Months")
plt.grid(True)

tick_locations = pd.date_range(start='2023-01-01', periods=4, freq='4MS')
tick_labels = ['Jan','May', 'Sept', 'Dec']
ax.set_xticks(tick_locations)
ax.set_xticklabels(tick_labels)

plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Direct WUE line plot, more messy

# Load data
df = pd.read_csv("TotalWue_Belgium.csv")
df_res = pd.read_csv("TotalWue_Denmark.csv")
df1 = pd.read_csv("TotalWue_Finland.csv")
df2 = pd.read_csv("TotalWue_Germany.csv")
df3 = pd.read_csv("TotalWue_Ireland.csv")
df4 = pd.read_csv("TotalWue_Netherlands1.csv")
df5 = pd.read_csv("TotalWue_Netherlands2.csv")
df6 = pd.read_csv("TotalWue_Norway.csv")
df7 = pd.read_csv("TotalWue_UK.csv")

# Convert gal/kWh to L/kWh

df["directWue L/kWh"] = df["directWue"] * 3.78541
df_res["directWue L/kWh"] = df_res["directWue"] * 3.78541
df1["directWue L/kWh"] = df1["directWue"] * 3.78541
df2["directWue L/kWh"] = df2["directWue"] * 3.78541
df3["directWue L/kWh"] = df3["directWue"] * 3.78541
df4["directWue L/kWh"] = df4["directWue"] * 3.78541
df5["directWue L/kWh"] = df5["directWue"] * 3.78541
df6["directWue L/kWh"] = df6["directWue"] * 3.78541
df7["directWue L/kWh"] = df7["directWue"] * 3.78541


df['MTU'] = pd.to_datetime(df['MTU'].str.split().str[0], format='%d.%m.%Y')
df_res['MTU'] = pd.to_datetime(df_res['MTU'].str.split().str[0], format='%d.%m.%Y')
df1['MTU'] = pd.to_datetime(df1['MTU'].str.split().str[0], format='%d.%m.%Y')
df2['MTU'] = pd.to_datetime(df2['MTU'].str.split().str[0], format='%d.%m.%Y')
df3['MTU'] = pd.to_datetime(df3['MTU'].str.split().str[0], format='%d.%m.%Y')
df4['MTU'] = pd.to_datetime(df4['MTU'].str.split().str[0], format='%d.%m.%Y')
df5['MTU'] = pd.to_datetime(df5['MTU'].str.split().str[0], format='%d.%m.%Y')
df6['MTU'] = pd.to_datetime(df6['MTU'].str.split().str[0], format='%d.%m.%Y')
df7['MTU'] = pd.to_datetime(df7['MTU'].str.split().str[0], format='%d.%m.%Y')

df.set_index('MTU', inplace=True)
df_res.set_index('MTU', inplace=True)
df1.set_index("MTU", inplace = True)
df2.set_index("MTU", inplace = True)
df3.set_index("MTU", inplace = True)
df4.set_index("MTU", inplace = True)
df5.set_index("MTU", inplace = True)
df6.set_index("MTU", inplace = True)
df7.set_index("MTU", inplace = True)

# Plotting
fig, ax = plt.subplots(figsize=(20, 10))


df["directWue L/kWh"].plot(kind='line', ax=ax, alpha=0.6, linewidth = 2, label='St. Ghislain, Belgium', color = 'm')
df_res["directWue L/kWh"].plot(kind='line', ax=ax, alpha=0.6, linewidth = 2, label='Fredericia, Denmark', color = 'c')
df1["directWue L/kWh"].plot(kind='line', ax=ax, alpha=0.6, linewidth = 2, label='Hamina, Finland', color = 'b')
df2["directWue L/kWh"].plot(kind='line', ax=ax, alpha=0.6, linewidth = 2, label='Hanau, Germany', color = 'k')
df3["directWue L/kWh"].plot(kind='line', ax=ax, alpha=0.6, linewidth = 2, label='Dublin, Ireland')
df4["directWue L/kWh"].plot(kind='line', ax=ax, alpha=0.6, linewidth = 2, label='Eemshaven, Netherlands')
df5["directWue L/kWh"].plot(kind='line', ax=ax, alpha=0.6, linewidth = 2, label='Middenmeer, Netherlands')
df6["directWue L/kWh"].plot(kind='line', ax=ax, alpha=0.6, linewidth = 2, label='Skien, Norway')
df7["directWue L/kWh"].plot(kind='line', ax=ax, alpha=0.6, linewidth = 2, label='Waltham Cross, UK')

# Setting title and labels
plt.title("Direct WUE")
plt.ylabel("WUE (L/kWh)")
plt.xlabel("Months")
plt.grid(True)

tick_locations = pd.date_range(start='2023-01-01', periods=4, freq='4MS')
tick_labels = ['Jan','May', 'Sept', 'Dec']
ax.set_xticks(tick_locations)
ax.set_xticklabels(tick_labels)

plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Direct WUE box plot (average )

# Load data
df = pd.read_csv("TotalWue_Belgium.csv")
df_res = pd.read_csv("TotalWue_Denmark.csv")
df1 = pd.read_csv("TotalWue_Finland.csv")
df2 = pd.read_csv("TotalWue_Germany.csv")
df3 = pd.read_csv("TotalWue_Ireland.csv")
df4 = pd.read_csv("TotalWue_Netherlands1.csv")
df5 = pd.read_csv("TotalWue_Netherlands2.csv")
df6 = pd.read_csv("TotalWue_Norway.csv")
df7 = pd.read_csv("TotalWue_UK.csv")

# Convert gal/kWh to L/kWh

for df in [df, df_res, df1, df2, df3, df4, df5, df6, df7]:
    df['directWue L/kWh'] = df['directWue'] * 3.78541

all_direct_wue = [df["directWue L/kWh"], df_res["directWue L/kWh"], df1["directWue L/kWh"], df2["directWue L/kWh"], df3["directWue L/kWh"],
                  df4["directWue L/kWh"], df5["directWue L/kWh"], df6["directWue L/kWh"], df7["directWue L/kWh"]]

fig, ax = plt.subplots(figsize = (20, 10))
ax.boxplot(all_direct_wue, vert = True, patch_artist = True, medianprops = dict(color = "black", linewidth = 1.5), boxprops = dict(facecolor = "lightgreen"), showfliers = False, showmeans = True, meanprops = {"marker": "D", "markerfacecolor":"yellow", "markeredgecolor":"black" })

labels = ["St. Ghislain, Belgium", 'Fredericia, Denmark', 'Hamina, Finland', 'Hanau, DE (Germany)', 'Dublin, Ireland', 'Eemshaven, Netherlands',
          'Middenmeer, Netherlands', 'Skien, Norway', 'Waltham Cross, UK']

plt.xticks(range(1, len(all_direct_wue) + 1), labels)
plt.xticks(rotation = 90, ha = 'right', fontsize = 14)
plt.yticks(fontsize = 14)

plt.title("Average WUE across different locations (Direct)", fontsize = 16)
plt.ylabel("WUE (L/kWh)", fontsize = 16)
plt.xlabel("Locations", fontsize = 16)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# Step 1: Read the dataset
df = pd.read_csv('TotalWue_Belgium.csv')
df_res = pd.read_csv('TotalWue_Denmark.csv')
df1 = pd.read_csv('TotalWue_Finland.csv')
df2 = pd.read_csv('TotalWue_Germany.csv')
df3 = pd.read_csv('TotalWue_Ireland.csv')
df4 = pd.read_csv('TotalWue_Netherlands1.csv')
df5 = pd.read_csv('TotalWue_Netherlands2.csv')
df6 = pd.read_csv('TotalWue_Norway.csv')
df7 = pd.read_csv('TotalWue_UK.csv')

for df in [df, df_res, df1, df2, df3, df4, df5, df6, df7]:
    df['start_time'] = df['MTU'].str.split(' - ').str[0]
    df['start_time'] = df['start_time'].str.split(' \\(').str[0]

for df in [df, df_res, df1, df2, df3, df4, df5, df6, df7]:
    df['start_time'] = pd.to_datetime(df['start_time'], format='%d.%m.%Y %H:%M')


df = df.set_index('start_time')
df_res = df_res.set_index('start_time')
df1 = df1.set_index('start_time')
df2 = df2.set_index('start_time')
df3 = df3.set_index('start_time')
df4 = df4.set_index('start_time')
df5 = df5.set_index('start_time')
df6 = df6.set_index('start_time')
df7 = df7.set_index('start_time')

for df in [df, df_res, df1, df2, df3, df4, df5, df6, df7]:
    df['directWue L/kWh'] = df['directWue'] * 3.78541

# Step 6: Calculate percentage change over 24-hour periods
for df in [df, df_res, df1, df2, df3, df4, df5, df6, df7]:
    df['WUE_percentage_change'] = abs(df['directWue L/kWh'].pct_change(periods=24) * 100)

for df in [df, df_res, df1, df2, df3, df4, df5, df6, df7]:
    df.dropna(subset=['WUE_percentage_change'], inplace=True)

all_direct_wue = [
    df['WUE_percentage_change'],
    df_res['WUE_percentage_change'],
    df1['WUE_percentage_change'],
    df2['WUE_percentage_change'],
    df3['WUE_percentage_change'],
    df4['WUE_percentage_change'],
    df5['WUE_percentage_change'],
    df6['WUE_percentage_change'],
    df7['WUE_percentage_change'] ]



# Creating a DataFrame for seaborn
all_direct_wue_df = pd.concat(all_direct_wue, axis=1)
all_direct_wue_df.columns = ["St. Ghislain, Belgium", "Fredericia, Denmark", "Hamina, Finland", "Hanau, Germany", "Dublin, Ireland",
                             "Eemshaven, Netherlands", "Middenmeer, Netherlands", "Skien, Norway", "Waltham Cross, UK"]
all_direct_wue_melted = all_direct_wue_df.melt(var_name="Locations", value_name="Percentage Change (%)")

fig, ax = plt.subplots(figsize=(15, 10))
sb.boxplot(
    x="Locations",
    y="Percentage Change (%)",
    data=all_direct_wue_melted,
    orient="v",
    color="lightgreen",
    showmeans=True, showfliers = False,
    boxprops={"facecolor": "lightgreen", "linewidth": 3},
    medianprops={"color": "black", "linewidth": 1.5},
    meanprops={"marker": "D", "markerfacecolor": "yellow", "markeredgecolor": "black"},
    whiskerprops={"linestyle": "-", "linewidth": 2, "color": "black"}
)

plt.title('Percentage Change of WUE Over 24-Hour Periods', fontsize=16)
plt.xlabel('Locations', fontsize=14)
plt.ylabel('Percentage Change (%)', fontsize=14)
plt.ylim(0, 100)
plt.grid(True)
plt.xticks(rotation=90, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
